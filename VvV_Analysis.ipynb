# %%
import mpl_style
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.style.use(mpl_style.style1)

# %%
df1 = pd.read_csv('Export_run1_wVel.csv')
df2 = pd.read_csv('Export_run2_wVel.csv')
df3 = pd.read_csv('Export_run3_wVel.csv')
df4 = pd.read_csv('Export_run4_wVel.csv')
df5 = pd.read_csv('Export_run5_wVel.csv')
df6 = pd.read_csv('Export_run6_wVel.csv')
df7 = pd.read_csv('Export_run7_wVel.csv')
df8 = pd.read_csv('Export_run8_wVel.csv')
df9 = pd.read_csv('Export_run9_wVel.csv')
df10 = pd.read_csv('Export_run10_wVel.csv')
df11 = pd.read_csv('Export_run11_wVel.csv')
df1.head()
# Out:
#    Velocity Mag:0  Velocity Mag:1  Velocity Mag:2   Density  Momentum:0  \
# 0          7376.0    3.450000e-13    4.080000e-13  0.000254      1.8701
# 1          7376.0    3.520000e-13    3.920000e-13  0.000254      1.8701
# 2          7376.0    3.590000e-13    3.760000e-13  0.000254      1.8701
# 3          7376.0    3.660000e-13    3.600000e-13  0.000254      1.8701
# 4          7376.0    3.730000e-13    3.440000e-13  0.000254      1.8701
#
#      Momentum:1    Momentum:2  Energy  Pressure  Temperature  ...  \
# 0  8.750000e-17  1.030000e-16  6941.2    17.661       242.65  ...
# 1  8.930000e-17  9.940000e-17  6941.2    17.661       242.65  ...
# 2  9.100000e-17  9.530000e-17  6941.2    17.661       242.65  ...
# 3  9.280000e-17  9.120000e-17  6941.2    17.661       242.65  ...
# 4  9.460000e-17  8.720000e-17  6941.2    17.661       242.65  ...
#
#    Residual_Density  Residual_Momentum:0  Residual_Momentum:1  \
# 0      1.270000e-21         1.040000e-17         9.830000e-19
# ...

# %%
def mag_calc(df):
    mag_list = []
    for i in range(0, len(df)):
        v_x = df['Velocity Mag:0']
        v_y = df['Velocity Mag:1']
        v_z = df['Velocity Mag:2']
        magnitude = np.sqrt(v_x[i]**2 + v_y[i]**2 + v_z[i]**2)
        print(magnitude)
        mag_list.append(magnitude)
        
    return mag_list

# %%
# mag_v1 = []
# for i in range(0, len(v_x1)):
#     magnitude = np.sqrt(v_x1[i]**2 + v_y1[i]**2 + v_z1[i]**2)
#     #print(magnitude)
#     mag_v1.append(magnitude)
# print(mag_v1)

# mag_v2 = []
# for i in range(0, len(v_x2)):
#     magnitude = np.sqrt(v_x2[i]**2 + v_y2[i]**2 + v_z2[i]**2)
#     #print(magnitude)
#     mag_v2.append(magnitude)
    
# #print(mag_v1)
# mag_v3 = []
# for i in range(0, len(v_x3)):
#     magnitude = np.sqrt(v_x3[i]**2 + v_y3[i]**2 + v_z3[i]**2)
#     #print(magnitude)
#     mag_v3.append(magnitude)
    
# mag_v4 = []
# for i in range(0, len(v_x4)):
#     magnitude = np.sqrt(v_x4[i]**2 + v_y4[i]**2 + v_z4[i]**2)
#     #print(magnitude)
#     mag_v4.append(magnitude)
    
# mag_v5 = []
# for i in range(0, len(v_x5)):
#     magnitude = np.sqrt(v_x5[i]**2 + v_y5[i]**2 + v_z5[i]**2)
#     #print(magnitude)
#     mag_v5.append(magnitude)
    
# mag_v6 = []
# for i in range(0, len(v_x6)):
#     magnitude = np.sqrt(v_x6[i]**2 + v_y6[i]**2 + v_z6[i]**2)
#     #print(magnitude)
#     mag_v6.append(magnitude)    
    
# mag_v7 = []
# for i in range(0, len(v_x7)):
#     magnitude = np.sqrt(v_x7[i]**2 + v_y7[i]**2 + v_z7[i]**2)
#     #print(magnitude)
#     mag_v7.append(magnitude)
    
# mag_v8 = []
# for i in range(0, len(v_x8)):
#     magnitude = np.sqrt(v_x8[i]**2 + v_y8[i]**2 + v_z8[i]**2)
#     #print(magnitude)
#     mag_v8.append(magnitude)
    
# mag_v9 = []
# for i in range(0, len(v_x9)):
#     magnitude = np.sqrt(v_x9[i]**2 + v_y9[i]**2 + v_z9[i]**2)
#     #print(magnitude)
#     mag_v9.append(magnitude)
    
# mag_v10 = []
# for i in range(0, len(v_x10)):
#     magnitude = np.sqrt(v_x10[i]**2 + v_y10[i]**2 + v_z10[i]**2)
#     #print(magnitude)
#     mag_v10.append(magnitude)
    
# mag_v11 = []
# for i in range(0, len(v_x11)):
#     magnitude = np.sqrt(v_x11[i]**2 + v_y11[i]**2 + v_z11[i]**2)
#     #print(magnitude)
#     mag_v11.append(magnitude)

# %%
v1 = mag_calc(df1)
v2 = mag_calc(df2)
v3 = mag_calc(df3)
v4 = mag_calc(df4)
v5 = mag_calc(df5)
v6 = mag_calc(df6)
v7 = mag_calc(df7)
v8 = mag_calc(df8)
v9 = mag_calc(df9)
v10 = mag_calc(df10)
v11 = mag_calc(df11)
# Out:
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# 7376.0
# ...

# %%
plt.plot(v1, v2)
plt.plot(v1, v3)
plt.plot(v1, v4)
plt.plot(v1, v5)
plt.plot(v1, v6)
plt.plot(v1, v7)
plt.plot(v1, v8)
plt.plot(v1, v9)
plt.plot(v1, v10)
plt.plot(v1, v11)
plt.xlabel('Velocity Mag, Run 1 [m/s]')
plt.ylabel('Velocity Mag, Run N [m/s]')
plt.legend(["run 2", "run 3", "run 4", "run 6", "run 7", "run 8", "run 9", "run 10", "run 11"], loc ="upper left", prop={'size': 10})
#plt.xlim(7500, 12000)
#plt.ylim(18000, 26000)
plt.show()

# %%
model = np.poly1d(np.polyfit(v1, v2, 3))
model2 = np.poly1d(np.polyfit(v1, v3, 3))
model3 = np.poly1d(np.polyfit(v1, v4, 3))
model4 = np.poly1d(np.polyfit(v1, v5, 3))
model5 = np.poly1d(np.polyfit(v1, v6, 3))
model6 = np.poly1d(np.polyfit(v1, v7, 3))
model7 = np.poly1d(np.polyfit(v1, v8, 3))
model8 = np.poly1d(np.polyfit(v1, v9, 3))
model9 = np.poly1d(np.polyfit(v1, v10, 3))
model10 = np.poly1d(np.polyfit(v1, v11, 3))

# %%
polyline = np.linspace(1, 8000, 50)
fig, ax = plt.subplots(1, 2)
fig.subplots_adjust(bottom = 0.5, top = 1.5, right = 2.5)
ax[0].scatter(v1, v2)
ax[0].scatter(v1, v3)
ax[0].scatter(v1, v4)
ax[0].scatter(v1, v5)
ax[0].scatter(v1, v6)
ax[0].plot(polyline, model(polyline))
ax[0].plot(polyline, model2(polyline))
ax[0].plot(polyline, model3(polyline))
ax[0].plot(polyline, model4(polyline))
ax[0].plot(polyline, model5(polyline))
ax[0].legend(["run 1", "run 2", "run 3", "run 4", "run 5"], loc ="upper left", prop={'size': 16})
ax[0].set(xlabel='Velocity Mag, Run 1 [m/s]')
ax[0].set(ylabel='Velocity Mag, Run N [m/s]')
ax[0].set(title='Velocity Magnitude Functions (Regime 1)')

ax[1].scatter(v1, v7)
ax[1].scatter(v1, v8)
ax[1].scatter(v1, v9)
ax[1].scatter(v1, v10)
ax[1].scatter(v1, v11)
ax[1].plot(polyline, model6(polyline))
ax[1].plot(polyline, model7(polyline))
ax[1].plot(polyline, model8(polyline))
ax[1].plot(polyline, model9(polyline))
ax[1].plot(polyline, model10(polyline))
ax[1].legend(["run 6", "run 7", "run 8", "run 9", "run 10"], loc ="upper left", prop={'size': 16})
ax[1].set(xlabel='Velocity Mag, Run 1 [m/s]')
ax[1].set(ylabel='Velocity Mag, Run N [m/s]')
ax[1].set(title='Velocity Magnitude Functions (Regime 2)')
#plt.savefig('VvV_Prime_MultiPlot.png', dpi=1200, format='png', bbox_inches='tight')
plt.show()

# %%
polyline = np.linspace(1, 8000, 50)

plt.scatter(v1, v2)
plt.scatter(v1, v3)
plt.scatter(v1, v4)
plt.scatter(v1, v5)
plt.scatter(v1, v6)
plt.scatter(v1, v7)
plt.scatter(v1, v8)
plt.scatter(v1, v9)
plt.scatter(v1, v10)
plt.scatter(v1, v11)
plt.plot(polyline, model(polyline))
plt.plot(polyline, model2(polyline))
plt.plot(polyline, model3(polyline))
plt.plot(polyline, model4(polyline))
plt.plot(polyline, model5(polyline))
plt.plot(polyline, model6(polyline))
plt.plot(polyline, model7(polyline))
plt.plot(polyline, model8(polyline))
plt.plot(polyline, model9(polyline))
plt.plot(polyline, model10(polyline))
plt.legend(["run 2", "run 3", "run 4", "run 5", "run 6", "run 7", 'run 8', "run 9", "run 10", "run 11"], loc ="upper left", prop={'size': 10})
plt.xlabel('Velocity Mag, Run 1 [m/s]')
plt.ylabel('Velocity Mag, Run N [m/s]')
plt.title("Combined Runs")
plt.show()

# %%
av_val_regime1 = []
for i in range(0, len(v1)):
    av_value_regime1 = (v2[i] + v3[i] + v4[i] + v5[i] + v6[i]) / 5
    av_val_regime1.append(av_value_regime1)
print(av_val_regime1)

av_val_regime2 = []
for i in range(0, len(v1)):
    av_value_regime2 = (v7[i] + v8[i] + v9[i] + v10[i] + v11[i]) / 5
    av_val_regime2.append(av_value_regime2)
print(av_val_regime2)
# Out:
# [7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.1, 7400.
# ...

# %%
model_av_regime1 = np.poly1d(np.polyfit(v1, av_val_regime1, 3))
print(model_av_regime1)
model_av_regime1_str = str(model_av_regime1)
print(model_av_regime1_str)
polyline_av_regime1 = np.linspace(1, 8000, 50)
plt.scatter(v1, av_val_regime1, alpha=0.8, s=9)
plt.plot(polyline_av_regime1, model_av_regime1(polyline_av_regime1), color='r')
plt.xlabel('Run 1 Velocity Magnitude [m/s]')
plt.ylabel('Run Averaged Velocity Magnitude [m/s]')
plt.legend(["Average Fitting Function"], loc='upper left', prop={'size': 16})
plt.annotate(model_av_regime1_str, xy =(3.3, 1),
                xytext =(1000, 500), fontsize = 12  
                )
plt.title('Average Velocity Mag Function Regime 1')
#plt.savefig('VvV_prime_Function_regime1.png', dpi=1200, format='png', bbox_inches='tight')
plt.show()
# Out:
#            3             2
# 6.521e-09 x - 4.757e-05 x + 0.9593 x + 294.9
#            3             2
# 6.521e-09 x - 4.757e-05 x + 0.9593 x + 294.9

# %%
model_av_regime2 = np.poly1d(np.polyfit(v1, av_val_regime2, 3))
print(model_av_regime2)
model_av_regime2_str = str(model_av_regime2)
print(model_av_regime2_str)
polyline_av_regime2 = np.linspace(1, 8000, 50)
plt.scatter(v1, av_val_regime2, alpha=0.8, s=9)
plt.plot(polyline_av_regime2, model_av_regime2(polyline_av_regime2), color='r')
plt.xlabel('Run 1 Velocity Magnitude [m/s]')
plt.ylabel('Run Averaged Velocity Magnitude [m/s]')
plt.legend(["Average Fitting Function"], loc='upper left', prop={'size': 16})
plt.annotate(model_av_regime1_str, xy =(3.3, 1),
                xytext =(1000, 500), fontsize = 12  
                )
plt.title('Average Velocity Mag Function Regime 2')
#plt.savefig('VvV_prime_Function_regime2.png', dpi=1200, format='png', bbox_inches='tight')
plt.show()
# Out:
#            3           2
# 9.836e-08 x - 0.00104 x + 3.331 x - 750.9
#            3           2
# 9.836e-08 x - 0.00104 x + 3.331 x - 750.9

# %%
df1_Test = pd.read_csv('TestCase1.csv')
df2_Test = pd.read_csv('TestCase2.csv')
df3_Test = pd.read_csv('TestCase3_v2.csv')
df4_Test = pd.read_csv('TestCase4.csv')
df5_Test = pd.read_csv('TestCase5.csv')
df6_Test = pd.read_csv('TestCase6.csv')

# %%
mag_v1_test = mag_calc(df1_Test)
mag_v2_test = mag_calc(df2_Test)
mag_v3_test = mag_calc(df3_Test)
mag_v4_test = mag_calc(df4_Test)
mag_v5_test = mag_calc(df5_Test)
mag_v6_test = mag_calc(df6_Test)
# Out:
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# 7367.2
# ...

# %%
def VelMagScalePlotRegime1(df):
    plt.scatter(v1, df)
    for i in range(0, len(df)):
        if df[1] <= 8000:
            plt.plot(polyline_av_regime1, (model_av_regime1(polyline_av_regime1) / 1), color='red')
        else:
            plt.plot(polyline_av_regime1, (model_av_regime1(polyline_av_regime1) / 1))

# %%
VelMagScalePlotRegime1(mag_v1_test)
VelMagScalePlotRegime1(mag_v2_test)
VelMagScalePlotRegime1(mag_v3_test)
plt.title('Velocity Mag Test Case Regime 1')
#plt.legend(["Test Run 1", "Test Run 2"], loc='upper left', prop={'size': 16})
plt.show()

# %%
def VelMagScalePlotRegime2(df):
    plt.scatter(v1, df)
    for i in range(0, len(df)):
        if df[1] <= 8000:
            plt.plot(polyline_av_regime2, (model_av_regime2(polyline_av_regime2) / 1), color='red')
        else:
            plt.plot(polyline_av_regime2, (model_av_regime2(polyline_av_regime2) / 1))

# %%
VelMagScalePlotRegime2(mag_v4_test)
VelMagScalePlotRegime2(mag_v5_test)
VelMagScalePlotRegime2(mag_v6_test)
plt.title('Velocity Mag Test Case Regime 1')
#plt.legend(["Test Run 4", "Test Run 5"], loc='upper left', prop={'size': 16})
plt.show()
